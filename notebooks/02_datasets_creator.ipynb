# %%
import pandas as pd, numpy as np, re, zipfile
from pathlib import Path

excel_path = "Datos finales para análisis IA _proyecto ENTOMOTIVE_.xlsx"

# %%
# ---------- helpers ----------
def make_unique_columns(df):
    cols = list(df.columns)
    seen = {}
    new_cols = []
    for c in cols:
        if c not in seen: # First time seen, add as is
            seen[c] = 0
            new_cols.append(c)
        else: # Already exists, add with prefix __dupN
            seen[c] += 1
            new_cols.append(f"{c}__dup{seen[c]}")
    df = df.copy()
    df.columns = new_cols
    return df

def norm_treat(x): # normalize treatment names
    if pd.isna(x):
        return np.nan
    if isinstance(x,(int,np.integer)):
        return str(int(x))
    if isinstance(x,(float,np.floating)):
        if float(x).is_integer():
            return str(int(x))
        return str(x)
    s=str(x).strip()
    if re.fullmatch(r"\d+\.0+", s): # integer float like "3.0"
        return s.split('.')[0]
    return s

def clean_mean_sd_sheet_from_header12(sheet_name):
    df = pd.read_excel(excel_path, sheet_name=sheet_name, header=[1,2])
    first_row = df.iloc[0] # to get subtypes
    new_cols=[]

    for col in df.columns:
        lvl0,lvl1 = col if isinstance(col, tuple) else (col, col)
        base = str(lvl1).strip() # main name
        subtype = str(first_row[col]).strip()
        if base in ["Dieta","Tratamiento"]:
            new_cols.append(base) # This column stays as is
        else:
            if subtype.lower() in ["media","mean"]:
                new_cols.append(f"{base}_media")
            elif subtype.lower() in ["sd","std","desviacion","desviación","desviacion estandar","desviación estándar"]:
                new_cols.append(f"{base}_sd")
            else:
                new_cols.append(base) # No matching subtype, keep base name
    df.columns=new_cols
    df = df.iloc[1:].reset_index(drop=True)
    df = df[df["Dieta"].notna()]
    df = df[df["Dieta"]!="Dieta"]
    df["Dieta"] = df["Dieta"].astype(str).str.strip()
    df["Tratamiento"] = df["Tratamiento"].apply(norm_treat)
    return make_unique_columns(df)

def clean_productivos(sheet_name):
    # Cleaning column names from extra spaces, etc.
    df = pd.read_excel(excel_path, sheet_name=sheet_name, header=2)
    df = df.dropna(subset=["Dieta"]) # remove rows with "Dieta = NaN"
    df = df[df["Dieta"]!="Dieta"].reset_index(drop=True) # remove repeated header rows
    df["Dieta"] = df["Dieta"].astype(str).str.strip()
    df["Tratamiento"] = df["Tratamiento"].apply(norm_treat) # normalize treatment names
    if "FCR " in df.columns and "FCR" not in df.columns:
        df = df.rename(columns={"FCR ":"FCR"})
    return make_unique_columns(df)

def clean_larvas(sheet_name):
    # Cleaning column names from extra spaces, etc.
    df = pd.read_excel(excel_path, sheet_name=sheet_name, header=2)
    df = df.dropna(subset=["Dieta"])
    df = df[df["Dieta"]!="Dieta"].reset_index(drop=True)
    df["Dieta"] = df["Dieta"].astype(str).str.strip()
    df["Tratamiento"] = df["Tratamiento"].apply(norm_treat)
    return make_unique_columns(df)

def clean_tpc(sheet_name):
    df = pd.read_excel(excel_path, sheet_name=sheet_name, header=[1,2])
    df.columns = ["Dieta","Tratamiento","TPC_dieta_media","TPC_dieta_sd","TPC_larva_media","TPC_larva_sd"]
    df = df[df["Dieta"].notna()]
    df = df[df["Dieta"]!="Dieta"].reset_index(drop=True)
    df["Dieta"] = df["Dieta"].astype(str).str.strip()
    df["Tratamiento"] = df["Tratamiento"].apply(norm_treat)
    return make_unique_columns(df)

def add_replica(df, by_cols):
    # Add Replica column based on cumulative count within groups defined by by_cols
    # for example, by_cols = ["Dieta","Tratamiento"] will number replicas for each Dieta-Tratamiento combination
    df = df.copy()
    df["Replica"] = df.groupby(by_cols).cumcount() + 1
    return make_unique_columns(df)

def parse_diet_name(dieta):
    # Parse diet name into structured components for analysis
    s = str(dieta).strip()
    byproduct = None
    inclusion = np.nan
    water = "none"
    processing = "none"
    study_block = "main"

    # In this block, we check for specific diet name patterns and extract relevant info
    '''
    byproduct: type of byproduct used (e.g., cafe, orujillo, control, hoja, orujo, quinoa, other)
    inclusion: percentage of byproduct inclusion in the diet
    water: water condition (dry, agar, humidity, none)
    processing: processing method (lyophilized, oven, none)
    study_block: experimental block (water_control, coffee_orujillo, main)
    '''

    if s.lower().startswith("control ") and any(k in s.lower() for k in ["seco","agar","humedad"]):
        byproduct="control"; inclusion=0; study_block="water_control"
        if "seco" in s.lower(): water="dry"
        elif "agar" in s.lower(): water="agar"
        elif "humedad" in s.lower(): water="humidity"
        return dict(diet_name=s, byproduct_type=byproduct, inclusion_pct=inclusion,
                    water_condition=water, processing=processing, study_block=study_block)
    if s.lower().startswith("posos café"):
        byproduct="cafe"; study_block="coffee_orujillo"
        m=re.search(r"(\d+)", s); inclusion=int(m.group(1)) if m else np.nan
        if "liof" in s.lower(): processing="lyophilized"
        elif "horno" in s.lower(): processing="oven"
        return dict(diet_name=s, byproduct_type=byproduct, inclusion_pct=inclusion,
                    water_condition=water, processing=processing, study_block=study_block)
    if s.lower().startswith("orujillo"):
        byproduct="orujillo"; study_block="coffee_orujillo"
        m=re.search(r"(\d+)", s); inclusion=int(m.group(1)) if m else np.nan
        return dict(diet_name=s, byproduct_type=byproduct, inclusion_pct=inclusion,
                    water_condition=water, processing=processing, study_block=study_block)
    if s.lower()=="control":
        byproduct="control"; inclusion=0
    else:
        m=re.match(r"(Hoja|Orujo|Quinoa)(\d+)", s, flags=re.IGNORECASE)
        if m:
            byproduct=m.group(1).lower(); inclusion=int(m.group(2))
        else:
            byproduct="other"
    return dict(diet_name=s, byproduct_type=byproduct, inclusion_pct=inclusion,
                water_condition=water, processing=processing, study_block=study_block)

def add_ratios(df):
    # Add nutritional ratios to the dataframe
    df=df.copy()
    needed=["Proteína (%)_media","Grasa (%)_media","Fibra (%)_media","Cenizas (%)_media","Carbohidratos (%)_media"]
    if not all(c in df.columns for c in needed):
        return df
    df["ratio_P_C"]=df["Proteína (%)_media"]/df["Carbohidratos (%)_media"]
    df["ratio_P_F"]=df["Proteína (%)_media"]/df["Grasa (%)_media"]
    df["ratio_Fibra_Grasa"]=df["Fibra (%)_media"]/df["Grasa (%)_media"]
    return make_unique_columns(df)

# %% [markdown]
# ### Testing the functions

# %% [markdown]
# Dietas Hermetia

# %%
clean_mean_sd_sheet_from_header12("Dietas HERMETIA")
# Out:
#        Dieta Tratamiento Proteína (%)_media Proteína (%)_sd Grasa (%)_media  \
# 0    Control           0          18.175156        0.435439        2.766018
# 1     Hoja15           1          16.838123        0.258047        2.650274
# 2     Hoja30           2          15.137502         0.23809        2.622729
# 3     Hoja50           3          13.511368        0.191933        2.931321
# 4    Orujo30           4          16.626013        0.017579        5.906098
# 5    Orujo50           5          14.938607        0.268863        7.274675
# 6    Orujo70           6          14.352349        0.212814        9.500662
# 7    Orujo90           7          12.528128        0.461024       10.817841
# 8   Quinoa15           8          16.372397         0.19357        2.716249
# 9   Quinoa30           9          15.457511        0.388899        2.974883
# 10  Quinoa50          10          14.960211        0.331009        3.138289
#
#    Grasa (%)_sd Fibra (%)_media Fibra (%)_sd Cenizas (%)_media Cenizas (%)_sd  \
# 0      0.029604        2.513074     0.093525         22.034336        0.09653
# 1      0.023624        3.702291     0.181163         19.294028       0.081509
# 2      0.113278        5.223646     0.117353         16.872466       0.190969
# 3      0.041274        7.773009     0.197489         14.292793       0.163029
# 4      0.141556        7.152747     0.299425         19.922816       0.156563
# 5      0.126253       11.503109     0.117809         15.247487       0.318942
# 6      0.106972       14.993037     0.277609         13.500153       0.313608
# 7       0.13248       19.978773      0.23035         10.484394       0.378936
# 8      0.078263        2.354644     0.029709         19.603305       0.105794
# 9      0.104481        2.588872     0.189671         19.048045       0.254833
# 10     0.039354        3.197361     0.150798         16.076561       0.069115
#
#    Carbohidratos (%)_media Carbohidratos (%)_sd
# 0                54.511416             0.547815
# 1                57.515283             0.043625
# 2                60.143657             0.305668
# 3                61.491509             0.211804
# 4                50.392325             0.542995
# 5                51.036123             0.524178
# 6                47.653799             0.375975
# 7                46.190864              0.05529
# 8                58.953405             0.256057
# 9                59.930689              0.82327
# 10               62.627578             0.436872

# %% [markdown]
# Parametros Productivos Hermetia

# %%
clean_productivos("Parámetros productivos HERMETIA").head(5)
# Out:
#      Dieta Tratamiento       FCR  Ganancia de peso (mg) por larva  \
# 0  Control           0  1.767204                           138.77
# 1  Control           0  1.611845                           168.14
# 2  Control           0  1.469797                           163.20
# 3   Hoja15           1  1.933048                           113.42
# 4   Hoja15           1  1.371372                           146.50
#
#    Ganancia de peso (mg) media diaria por larva  \
# 0                                     11.564167
# 1                                     14.011667
# 2                                     13.600000
# 3                                      9.451667
# 4                                     12.208333
#
#    Reducción (%) del sustrato (reducción de la masa de dieta suministrada)  \
# 0                                          57.673863
# 1                                          68.672394
# 2                                          69.976968
# 3                                          70.544403
# 4                                          76.302053
#
#    Reducción diaria (%) del sustrato (reducción diaria de la masa de dieta suministrada)  \
# 0                                           4.806155
# 1                                           5.722699
# 2                                           5.831414
# 3                                           5.878700
# 4                                           6.358504
#
#    Peso total de las larvas (g) al finalizar el periodo de alimentación  \
# 0                                             1544.0
# 1                                             1983.5
# 2                                             2207.5
# 3                                             1739.5
# 4                                             2602.5
#
#    Peso total del sustrato (g) al finalizar el periodo de alimentación
# 0                                        1884.437753
# 1                                        1391.567280
# 2                                        1334.673548
# 3                                        1330.567333
# 4                                        1069.702232

# %% [markdown]
# Hermetia Larvas

# %%
clean_larvas("HERMETIA larvas").head(5)
# Out:
#      Dieta Tratamiento  PROTEINA (%)  GRASA (%)  QUITINA (%)  CENIZAS (%)  \
# 0  Control           0     32.298228   7.856994     4.536508    24.085233
# 1  Control           0     31.988273   9.178856     3.188548    23.805322
# 2  Control           0     31.522017  17.458388     4.024695    22.767007
# 3   Hoja15           1     32.439877   8.138716    10.804604    25.394843
# 4   Hoja15           1     31.861333   9.794866     7.392563    26.810799
#
#    CARBOHIDRATOS (%)
# 0          31.223037
# 1          31.839000
# 2          24.227893
# 3          23.221962
# 4          24.140439

# %% [markdown]
# TPC Hermetia

# %%
clean_tpc("TPC HERMETIA").head(5)
# Out:
#      Dieta Tratamiento TPC_dieta_media TPC_dieta_sd TPC_larva_media  \
# 0  Control           0        0.180416     0.012046        0.432843
# 1   Hoja15           1         0.90341     0.100583        0.358376
# 2   Hoja30           2        1.616542     0.050153        0.442705
# 3   Hoja50           3        2.484336       0.3436         0.31179
# 4  Orujo30           4        0.785741     0.110158        0.351143
#
#   TPC_larva_sd
# 0     0.031135
# 1     0.017351
# 2     0.046997
# 3     0.020487
# 4     0.044412

# %%
prod_T = clean_productivos("Parámetro productivos TENEBRIO")
prod_T_l = add_replica(prod_T, ["Dieta"])
larv_T_l = add_replica(larv_T, ["Dieta"])
prod_T_l["species"]="Tenebrio"; larv_T_l["species"]="Tenebrio"
# prod_T_l = add_comp_keys_T(prod_T_l)
# larv_T_l = add_comp_keys_T(larv_T_l)

prod_T_l.head(5)
# Out:
#      Dieta Tratamiento       FCR Ganancia de peso (mg) por larva  \
# 0  Control           0  2.965587                             NaN
# 1  Control           0  2.773211                            41.5
# 2  Control           0  2.727205                              48
# 3   Hoja15           1  2.542555                            37.1
# 4   Hoja15           1  2.855694                            37.8
#
#   Ganancia de peso (mg) media diaria por larva  \
# 0                                          NaN
# 1                                     0.846939
# 2                                     0.979592
# 3                                     0.757143
# 4                                     0.771429
#
#   Reducción (%) del sustrato (reducción de la masa de dieta suministrada)  \
# 0                                          34.183333
# 1                                          30.083333
# 2                                          30.533333
# 3                                          21.633333
# 4                                              20.65
#
#   Reducción diaria (%) del sustrato (reducción diaria de la masa de dieta suministrada)  \
# 0                                           4.883333
# 1                                           4.297619
# 2                                           4.361905
# 3                                           3.090476
# 4                                               2.95
#
#   Peso total de las larvas (g) al finalizar el periodo de alimentación  \
# 0                                                836
# 1                                                723
# 2                                                745
# 3                                                613
# 4                                                506
#
#   Peso total del sustrato (g) al finalizar el periodo de alimentación  \
# 0                                               3949
# 1                                               4195
# 2                                               4168
# 3                                               4702
# 4                                               4761
#
#    Replica   species Dieta_comp Trat_comp
# 0        1  Tenebrio    Control         0
# 1        2  Tenebrio    Control         0
# 2        3  Tenebrio    Control         0
# 3        1  Tenebrio     Hoja15         1
# 4        2  Tenebrio     Hoja15         1

# %%
# Larva dataframe joined with productivity dataframe
prod_T_ds = prod_T_l.merge(larv_T_l, on=["Dieta","Replica","species"], suffixes=("_prod","_larv"))

prod_T_ds["Dieta_comp"]=prod_T_ds["Dieta_comp_prod"]
prod_T_ds["Trat_comp"]=prod_T_ds["Trat_comp_prod"]
prod_T_ds["Tratamiento"]=prod_T_ds["Tratamiento_prod"]

prod_T_ds.head(5)
# Out:
#      Dieta Tratamiento_prod       FCR Ganancia de peso (mg) por larva  \
# 0  Control                0  2.965587                             NaN
# 1  Control                0  2.773211                            41.5
# 2  Control                0  2.727205                              48
# 3   Hoja15                1  2.542555                            37.1
# 4   Hoja15                1  2.855694                            37.8
#
#   Ganancia de peso (mg) media diaria por larva  \
# 0                                          NaN
# 1                                     0.846939
# 2                                     0.979592
# 3                                     0.757143
# 4                                     0.771429
#
#   Reducción (%) del sustrato (reducción de la masa de dieta suministrada)  \
# 0                                          34.183333
# 1                                          30.083333
# 2                                          30.533333
# 3                                          21.633333
# 4                                              20.65
#
#   Reducción diaria (%) del sustrato (reducción diaria de la masa de dieta suministrada)  \
# 0                                           4.883333
# 1                                           4.297619
# 2                                           4.361905
# 3                                           3.090476
# 4                                               2.95
#
#   Peso total de las larvas (g) al finalizar el periodo de alimentación  \
# 0                                                836
# 1                                                723
# 2                                                745
# 3                                                613
# 4                                                506
#
#   Peso total del sustrato (g) al finalizar el periodo de alimentación  \
# 0                                               3949
# 1                                               4195
# 2                                               4168
# 3                                               4702
# 4                                               4761
#
#    Replica  ... Dieta_comp_prod Trat_comp_prod Tratamiento_larv PROTEINA (%)  \
# 0        1  ...         Control              0                0    42.724278
# 1        2  ...         Control              0                0    43.798393
# 2        3  ...         Control              0                0    43.331882
# 3        1  ...          Hoja15              1                1    44.599669
# 4        2  ...          Hoja15              1                1    48.582073
#
#    GRASA (%) QUITINA (%) CENIZAS (%) CARBOHIDRATOS (%) Dieta_comp_larv  \
# 0  37.218749     5.87989    3.733378         10.443705         Control
# 1  32.105928    6.668637    4.028978         13.398064         Control
# 2   36.23092    6.428088    4.041571          9.967538         Control
# 3  35.773419    5.862071    4.110244          9.654598          Hoja15
# 4  33.395068    6.009969     4.40894           7.60395          Hoja15
#
#   Trat_comp_larv
# 0              0
# 1              0
# 2              0
# 3              1
# 4              1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Creating the Dataset

# %% [markdown]
# #### Loading data

# %%
diet_H = add_ratios(clean_mean_sd_sheet_from_header12("Dietas HERMETIA"))
diet_T = add_ratios(clean_mean_sd_sheet_from_header12("Dietas TENEBRIO"))
prod_H = clean_productivos("Parámetros productivos HERMETIA")
prod_T = clean_productivos("Parámetro productivos TENEBRIO")
larv_H = clean_larvas("HERMETIA larvas")
larv_T = clean_larvas("TENEBRIO larvas")
tpc_H = clean_tpc("TPC HERMETIA")
tpc_T = clean_tpc("TPC TENEBRIO")

control_variants = {"Control Seco","Control Agar","Control Humedad superf"}
def add_comp_keys_T(df):
    df=df.copy()
    df["Dieta_comp"]=df["Dieta"]
    df["Trat_comp"]=df["Tratamiento"]
    mask = df["Dieta"].isin(control_variants) | df["Tratamiento"].isin(["A.1","A.2","A.3"])
    df.loc[mask,"Dieta_comp"]="Control"
    df.loc[mask,"Trat_comp"]="A"
    return make_unique_columns(df)

# %% [markdown]
# #### Productivity Dataset

# %%
# Hermetia
prod_H_l = add_replica(prod_H, ["Dieta","Tratamiento"]) # Enumerate lots/replicas
larv_H_l = add_replica(larv_H, ["Dieta","Tratamiento"])
prod_H_l["species"]="Hermetia"; larv_H_l["species"]="Hermetia"
prod_H_ds = prod_H_l.merge(larv_H_l, on=["Dieta","Tratamiento","Replica","species"], suffixes=("_prod","_larv"))
prod_H_ds = prod_H_ds.merge(diet_H, on=["Dieta","Tratamiento"], how="left")
prod_H_ds = prod_H_ds.merge(tpc_H, on=["Dieta","Tratamiento"], how="left")
meta_H = pd.DataFrame([parse_diet_name(d) for d in prod_H_ds["Dieta"]])
prod_H_ds = make_unique_columns(pd.concat([prod_H_ds.reset_index(drop=True), meta_H.reset_index(drop=True)], axis=1))

# Tenebrio
prod_T_l = add_replica(prod_T, ["Dieta"])
larv_T_l = add_replica(larv_T, ["Dieta"])
prod_T_l["species"]="Tenebrio"; larv_T_l["species"]="Tenebrio"
prod_T_l = add_comp_keys_T(prod_T_l)
larv_T_l = add_comp_keys_T(larv_T_l)

# Joining Larva dataframe with productivity dataframe
prod_T_ds = prod_T_l.merge(larv_T_l, on=["Dieta","Replica","species"], suffixes=("_prod","_larv"))
prod_T_ds["Dieta_comp"]=prod_T_ds["Dieta_comp_prod"]
prod_T_ds["Trat_comp"]=prod_T_ds["Trat_comp_prod"]
prod_T_ds["Tratamiento"]=prod_T_ds["Tratamiento_prod"]
prod_T_ds = prod_T_ds.merge(diet_T, left_on=["Dieta_comp","Trat_comp"], right_on=["Dieta","Tratamiento"], how="left", suffixes=("","_diet"))

# Remove redundant columns after merge
for k in ["Dieta_diet","Tratamiento_diet"]:
    if k in prod_T_ds.columns: prod_T_ds = prod_T_ds.drop(columns=[k])

# Merge TPC data to productivity dataframe
prod_T_ds = prod_T_ds.merge(tpc_T, left_on=["Dieta_comp","Trat_comp"], right_on=["Dieta","Tratamiento"], how="left", suffixes=("","_tpc"))
for k in ["Dieta_tpc","Tratamiento_tpc"]:
    if k in prod_T_ds.columns: prod_T_ds = prod_T_ds.drop(columns=[k])

# Add parsed diet metadata
meta_T = pd.DataFrame([parse_diet_name(d) for d in prod_T_ds["Dieta"]])
prod_T_ds = make_unique_columns(pd.concat([prod_T_ds.reset_index(drop=True), meta_T.reset_index(drop=True)], axis=1))

prod_T_ds.head(5)
# Out:
#      Dieta Tratamiento_prod       FCR Ganancia de peso (mg) por larva  \
# 0  Control                0  2.965587                             NaN
# 1  Control                0  2.773211                            41.5
# 2  Control                0  2.727205                              48
# 3   Hoja15                1  2.542555                            37.1
# 4   Hoja15                1  2.855694                            37.8
#
#   Ganancia de peso (mg) media diaria por larva  \
# 0                                          NaN
# 1                                     0.846939
# 2                                     0.979592
# 3                                     0.757143
# 4                                     0.771429
#
#   Reducción (%) del sustrato (reducción de la masa de dieta suministrada)  \
# 0                                          34.183333
# 1                                          30.083333
# 2                                          30.533333
# 3                                          21.633333
# 4                                              20.65
#
#   Reducción diaria (%) del sustrato (reducción diaria de la masa de dieta suministrada)  \
# 0                                           4.883333
# 1                                           4.297619
# 2                                           4.361905
# 3                                           3.090476
# 4                                               2.95
#
#   Peso total de las larvas (g) al finalizar el periodo de alimentación  \
# 0                                                836
# 1                                                723
# 2                                                745
# 3                                                613
# 4                                                506
#
#   Peso total del sustrato (g) al finalizar el periodo de alimentación  \
# 0                                               3949
# 1                                               4195
# 2                                               4168
# 3                                               4702
# 4                                               4761
#
#    Replica  ... TPC_dieta_media TPC_dieta_sd TPC_larva_media TPC_larva_sd  \
# 0        1  ...        0.231935     0.002182        0.321229     0.023088
# 1        2  ...        0.231935     0.002182        0.321229     0.023088
# 2        3  ...        0.231935     0.002182        0.321229     0.023088
# 3        1  ...        0.993719     0.052006        0.363926     0.029128
# 4        2  ...        0.993719     0.052006        0.363926     0.029128
#
#   diet_name byproduct_type inclusion_pct water_condition processing  \
# 0   Control        control             0            none       none
# 1   Control        control             0            none       none
# 2   Control        control             0            none       none
# 3    Hoja15           hoja            15            none       none
# 4    Hoja15           hoja            15            none       none
#
#   study_block
# 0        main
# 1        main
# 2        main
# 3        main
# 4        main
#
# [5 rows x 47 columns]

# %%
def reorder_productivity(df):
    id_cols = ["species","study_block","diet_name","Dieta","Tratamiento","Replica","byproduct_type","inclusion_pct","water_condition","processing"]
    id_cols=[c for c in id_cols if c in df.columns]
    diet_cols=[c for c in df.columns if c.endswith("_media") or c.endswith("_sd") or c.startswith("ratio_")]
    y_prod=[
        "FCR",
        "Ganancia de peso (mg) por larva",
        "Ganancia de peso (mg) media diaria por larva",
        "Reducción (%) del sustrato (reducción de la masa de dieta suministrada)",
        "Reducción diaria (%) del sustrato (reducción diaria de la masa de dieta suministrada)",
        "Peso total de las larvas (g) al finalizar el periodo de alimentación",
        "Peso total del sustrato (g) al finalizar el periodo de alimentación",
    ]
    y_prod=[c for c in y_prod if c in df.columns]
    larv_cols=[c for c in ["PROTEINA (%)","GRASA (%)","QUITINA (%)","CENIZAS (%)","CARBOHIDRATOS (%)"] if c in df.columns]
    tpc_cols=[c for c in ["TPC_dieta_media","TPC_dieta_sd","TPC_larva_media","TPC_larva_sd"] if c in df.columns]
    remaining=[c for c in df.columns if c not in set(id_cols+diet_cols+y_prod+larv_cols+tpc_cols)]
    return make_unique_columns(df[id_cols+diet_cols+y_prod+larv_cols+tpc_cols+remaining])

# %%
prod_H_ds = reorder_productivity(prod_H_ds)
prod_T_ds = reorder_productivity(prod_T_ds)
prod_all_ds = pd.concat([make_unique_columns(prod_H_ds), make_unique_columns(prod_T_ds)], ignore_index=True, sort=False)

prod_all_ds
# Out:
#      species      study_block   diet_name       Dieta Tratamiento  Replica  \
# 0   Hermetia             main     Control     Control           0        1
# 1   Hermetia             main     Control     Control           0        2
# 2   Hermetia             main     Control     Control           0        3
# 3   Hermetia             main      Hoja15      Hoja15           1        1
# 4   Hermetia             main      Hoja15      Hoja15           1        2
# ..       ...              ...         ...         ...         ...      ...
# 85  Tenebrio  coffee_orujillo  Orujillo30  Orujillo30           E        2
# 86  Tenebrio  coffee_orujillo  Orujillo30  Orujillo30           E        3
# 87  Tenebrio  coffee_orujillo  Orujillo50  Orujillo50           F        1
# 88  Tenebrio  coffee_orujillo  Orujillo50  Orujillo50           F        2
# 89  Tenebrio  coffee_orujillo  Orujillo50  Orujillo50           F        3
#
#    byproduct_type  inclusion_pct water_condition processing  ...  \
# 0         control              0            none       none  ...
# 1         control              0            none       none  ...
# 2         control              0            none       none  ...
# 3            hoja             15            none       none  ...
# 4            hoja             15            none       none  ...
# ..            ...            ...             ...        ...  ...
# 85       orujillo             30            none       none  ...
# 86       orujillo             30            none       none  ...
# 87       orujillo             50            none       none  ...
# 88       orujillo             50            none       none  ...
# 89       orujillo             50            none       none  ...
#
#    TPC_larva_media__dup1 TPC_larva_sd__dup1 Tratamiento_prod Dieta_comp_prod  \
# 0               0.432843           0.031135              NaN             NaN
# 1               0.432843           0.031135              NaN             NaN
# 2               0.432843           0.031135              NaN             NaN
# 3               0.358376           0.017351              NaN             NaN
# 4               0.358376           0.017351              NaN             NaN
# ..                   ...                ...              ...             ...
# 85                   NaN                NaN                E      Orujillo30
# 86                   NaN                NaN                E      Orujillo30
# 87                   NaN                NaN                F      Orujillo50
# 88                   NaN                NaN                F      Orujillo50
# 89                   NaN                NaN                F      Orujillo50
#
#    Trat_comp_prod Tratamiento_larv Dieta_comp_larv Trat_comp_larv  Dieta_comp  \
# 0             NaN              NaN             NaN            NaN         NaN
# 1             NaN              NaN             NaN            NaN         NaN
# 2             NaN              NaN             NaN            NaN         NaN
# 3             NaN              NaN             NaN            NaN         NaN
# 4             NaN              NaN             NaN            NaN         NaN
# ..            ...              ...             ...            ...         ...
# 85              E              NaN      Orujillo30            NaN  Orujillo30
# 86              E              NaN      Orujillo30            NaN  Orujillo30
# 87              F              NaN      Orujillo50            NaN  Orujillo50
# 88              F              NaN      Orujillo50            NaN  Orujillo50
# 89              F              NaN      Orujillo50            NaN  Orujillo50
#
#    Trat_comp
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 85         E
# 86         E
# 87         F
# 88         F
# 89         F
#
# [90 rows x 51 columns]

# %% [markdown]
# #### Quality Dataset

# %%
def larva_agg_by_diet(df):
    cols=[c for c in ["PROTEINA (%)","GRASA (%)","QUITINA (%)","CENIZAS (%)","CARBOHIDRATOS (%)"] if c in df.columns]
    g=df.groupby("Dieta")[cols].agg(["mean","std"]).reset_index()
    new_cols=["Dieta"]
    for c in cols:
        new_cols += [f"{c}_mean", f"{c}_sd"]
    g.columns=new_cols
    return make_unique_columns(g)

# %% [markdown]
# Hermetia composition

# %%
qual_H = diet_H.copy()
qual_H["species"]="Hermetia"

# Add TPC and larva aggregated data
qual_H = qual_H.merge(tpc_H, on=["Dieta","Tratamiento"], how="left")

# Larva aggregrated data refers to all replicas of each diet with same diet and treatment
qual_H = qual_H.merge(larva_agg_by_diet(larv_H), on="Dieta", how="left")

qual_H = make_unique_columns(pd.concat([qual_H.reset_index(drop=True),
                                        pd.DataFrame([parse_diet_name(d) for d in qual_H["Dieta"]]).reset_index(drop=True)], axis=1))
qual_H.head(5)
# Out:
#      Dieta Tratamiento Proteína (%)_media Proteína (%)_sd Grasa (%)_media  \
# 0  Control           0          18.175156        0.435439        2.766018
# 1   Hoja15           1          16.838123        0.258047        2.650274
# 2   Hoja30           2          15.137502         0.23809        2.622729
# 3   Hoja50           3          13.511368        0.191933        2.931321
# 4  Orujo30           4          16.626013        0.017579        5.906098
#
#   Grasa (%)_sd Fibra (%)_media Fibra (%)_sd Cenizas (%)_media Cenizas (%)_sd  \
# 0     0.029604        2.513074     0.093525         22.034336        0.09653
# 1     0.023624        3.702291     0.181163         19.294028       0.081509
# 2     0.113278        5.223646     0.117353         16.872466       0.190969
# 3     0.041274        7.773009     0.197489         14.292793       0.163029
# 4     0.141556        7.152747     0.299425         19.922816       0.156563
#
#    ... CENIZAS (%)_mean CENIZAS (%)_sd CARBOHIDRATOS (%)_mean  \
# 0  ...        23.552521       0.694522              29.096643
# 1  ...        26.271347       0.765791              24.788409
# 2  ...        20.199422       1.128735              24.414996
# 3  ...        20.929722       0.207798              29.368771
# 4  ...        20.538848       1.106628              30.074157
#
#   CARBOHIDRATOS (%)_sd diet_name byproduct_type inclusion_pct water_condition  \
# 0             4.227694   Control        control             0            none
# 1             1.971962    Hoja15           hoja            15            none
# 2             3.130644    Hoja30           hoja            30            none
# 3             2.589442    Hoja50           hoja            50            none
# 4             5.733730   Orujo30          orujo            30            none
#
#   processing study_block
# 0       none        main
# 1       none        main
# 2       none        main
# 3       none        main
# 4       none        main
#
# [5 rows x 36 columns]

# %% [markdown]
# Tenebrio Composition

# %%
qual_T = pd.DataFrame({"Dieta": sorted(larv_T["Dieta"].unique())})
qual_T["species"]="Tenebrio"
treat_lookup = prod_T.groupby("Dieta")["Tratamiento"].apply(lambda s: next((x for x in s if pd.notna(x)), np.nan)).to_dict()
treat_lookup
# Out:
# {'Control': '0',
#  'Control Agar': 'A.2',
#  'Control Humedad superf': 'A.3',
#  'Control Seco': 'A.1',
#  'Hoja15': '1',
#  'Hoja30': '2',
#  'Hoja50': '3',
#  'Orujillo15': 'D',
#  'Orujillo30': 'E',
#  'Orujillo50': 'F',
#  'Orujo30': '4',
#  'Orujo50': '5',
#  'Orujo70': '6',
#  'Orujo90': '7',
#  'Posos café horno15': 'C',
#  'Posos café liof15': 'B',
#  'Quinoa15': '8',
#  'Quinoa30': '9',
#  'Quinoa50': '10'}

# %%
def comp_pair(dieta):
    if dieta in control_variants:
        return ("Control","A")
    tr=treat_lookup.get(dieta, np.nan)
    if tr in ["A.1","A.2","A.3"]:
        return ("Control","A")
    return (dieta, tr)

pairs=[comp_pair(d) for d in qual_T["Dieta"]]
qual_T["Dieta_comp"]=[p[0] for p in pairs]
qual_T["Trat_comp"]=[p[1] for p in pairs]

qual_T
# Out:
#                      Dieta   species          Dieta_comp Trat_comp
# 0                  Control  Tenebrio             Control         0
# 1             Control Agar  Tenebrio             Control         A
# 2   Control Humedad superf  Tenebrio             Control         A
# 3             Control Seco  Tenebrio             Control         A
# 4                   Hoja15  Tenebrio              Hoja15         1
# 5                   Hoja30  Tenebrio              Hoja30         2
# 6                   Hoja50  Tenebrio              Hoja50         3
# 7               Orujillo15  Tenebrio          Orujillo15         D
# 8               Orujillo30  Tenebrio          Orujillo30         E
# 9               Orujillo50  Tenebrio          Orujillo50         F
# 10                 Orujo30  Tenebrio             Orujo30         4
# 11                 Orujo50  Tenebrio             Orujo50         5
# 12                 Orujo70  Tenebrio             Orujo70         6
# 13                 Orujo90  Tenebrio             Orujo90         7
# 14      Posos café horno15  Tenebrio  Posos café horno15         C
# 15       Posos café liof15  Tenebrio   Posos café liof15         B
# 16                Quinoa15  Tenebrio            Quinoa15         8
# 17                Quinoa30  Tenebrio            Quinoa30         9
# 18                Quinoa50  Tenebrio            Quinoa50        10

# %%
# Join diet data to quality dataframe with composition keys
qual_T = qual_T.merge(diet_T, left_on=["Dieta_comp","Trat_comp"], right_on=["Dieta","Tratamiento"], how="left", suffixes=("","_diet"))
for k in ["Dieta_diet","Tratamiento_diet"]:
    if k in qual_T.columns: qual_T = qual_T.drop(columns=[k])

# Merge TPC data to quality dataframe
qual_T = qual_T.merge(tpc_T, left_on=["Dieta_comp","Trat_comp"], right_on=["Dieta","Tratamiento"], how="left", suffixes=("","_tpc"))
for k in ["Dieta_tpc","Tratamiento_tpc"]:
    if k in qual_T.columns: qual_T = qual_T.drop(columns=[k])

# Merge larva aggregated data to quality dataframe
qual_T = qual_T.merge(larva_agg_by_diet(larv_T), on="Dieta", how="left")
qual_T = make_unique_columns(pd.concat([qual_T.reset_index(drop=True),
                                        pd.DataFrame([parse_diet_name(d) for d in qual_T["Dieta"]]).reset_index(drop=True)], axis=1))
qual_T.head(5)
# Out:
#                     Dieta   species Dieta_comp Trat_comp Tratamiento  \
# 0                 Control  Tenebrio    Control         0           0
# 1            Control Agar  Tenebrio    Control         A           A
# 2  Control Humedad superf  Tenebrio    Control         A           A
# 3            Control Seco  Tenebrio    Control         A           A
# 4                  Hoja15  Tenebrio     Hoja15         1           1
#
#   Proteína (%)_media Proteína (%)_sd Grasa (%)_media Grasa (%)_sd  \
# 0          14.567601         0.33907        2.847048     0.065187
# 1          12.755333        0.548518        1.246667     0.073711
# 2          12.755333        0.548518        1.246667     0.073711
# 3          12.755333        0.548518        1.246667     0.073711
# 4            12.9116        0.186512        2.477307     0.104573
#
#   Fibra (%)_media  ... CENIZAS (%)_mean CENIZAS (%)_sd CARBOHIDRATOS (%)_mean  \
# 0        2.415439  ...         3.934642       0.174414              11.269769
# 1             NaN  ...         3.432133       0.040046                    NaN
# 2             NaN  ...            3.378       0.034875                    NaN
# 3             NaN  ...         3.592833       0.028178                    NaN
# 4        3.813707  ...         4.134092       0.263735               9.751356
#
#   CARBOHIDRATOS (%)_sd               diet_name byproduct_type inclusion_pct  \
# 0             1.858471                 Control        control             0
# 1                  NaN            Control Agar        control             0
# 2                  NaN  Control Humedad superf        control             0
# 3                  NaN            Control Seco        control             0
# 4             2.197384                  Hoja15           hoja            15
#
#   water_condition processing    study_block
# 0            none       none           main
# 1            agar       none  water_control
# 2        humidity       none  water_control
# 3             dry       none  water_control
# 4            none       none           main
#
# [5 rows x 38 columns]

# %%
def reorder_quality(df):
    # Reorder columns in quality dataframe creating a consistent structure based on id, diet, TPC, and quality columns
    id_cols=["species","study_block","diet_name","Dieta","byproduct_type","inclusion_pct","water_condition","processing"]

    # Check if id cols exist in dataframe
    id_cols=[c for c in id_cols if c in df.columns]

    # Identify diet, tpc, quality and other related columns
    diet_cols=[c for c in df.columns if c.endswith("_media") or c.endswith("_sd") or c.startswith("ratio_")]
    tpc_diet=[c for c in ["TPC_dieta_media","TPC_dieta_sd"] if c in df.columns]
    y_quality=[c for c in df.columns if c.endswith("_mean")] + [c for c in ["TPC_larva_media","TPC_larva_sd"] if c in df.columns]
    remaining=[c for c in df.columns if c not in set(id_cols+diet_cols+tpc_diet+y_quality)]

    return make_unique_columns(df[id_cols+diet_cols+tpc_diet+y_quality+remaining])

# %%
qual_H = reorder_quality(qual_H)
qual_H.head(5)
# Out:
#     species study_block diet_name    Dieta byproduct_type  inclusion_pct  \
# 0  Hermetia        main   Control  Control        control              0
# 1  Hermetia        main    Hoja15   Hoja15           hoja             15
# 2  Hermetia        main    Hoja30   Hoja30           hoja             30
# 3  Hermetia        main    Hoja50   Hoja50           hoja             50
# 4  Hermetia        main   Orujo30  Orujo30          orujo             30
#
#   water_condition processing Proteína (%)_media Proteína (%)_sd  ...  \
# 0            none       none          18.175156        0.435439  ...
# 1            none       none          16.838123        0.258047  ...
# 2            none       none          15.137502         0.23809  ...
# 3            none       none          13.511368        0.191933  ...
# 4            none       none          16.626013        0.017579  ...
#
#   TPC_dieta_media__dup1 TPC_dieta_sd__dup1 PROTEINA (%)_mean GRASA (%)_mean  \
# 0              0.180416           0.012046         31.936173      11.498079
# 1               0.90341           0.100583         31.417118       8.225027
# 2              1.616542           0.050153         24.417325      21.223611
# 3              2.484336             0.3436         23.370496      14.909885
# 4              0.785741           0.110158         30.321931      10.156761
#
#   QUITINA (%)_mean CENIZAS (%)_mean CARBOHIDRATOS (%)_mean  \
# 0         3.916584        23.552521              29.096643
# 1         9.298099        26.271347              24.788409
# 2         9.744646        20.199422              24.414996
# 3        11.421126        20.929722              29.368771
# 4         8.908303        20.538848              30.074157
#
#   TPC_larva_media__dup1 TPC_larva_sd__dup1 Tratamiento
# 0              0.432843           0.031135           0
# 1              0.358376           0.017351           1
# 2              0.442705           0.046997           2
# 3               0.31179           0.020487           3
# 4              0.351143           0.044412           4
#
# [5 rows x 40 columns]

# %%
qual_T = reorder_quality(qual_T)
qual_T.head(5)
# Out:
#     species    study_block               diet_name                   Dieta  \
# 0  Tenebrio           main                 Control                 Control
# 1  Tenebrio  water_control            Control Agar            Control Agar
# 2  Tenebrio  water_control  Control Humedad superf  Control Humedad superf
# 3  Tenebrio  water_control            Control Seco            Control Seco
# 4  Tenebrio           main                  Hoja15                  Hoja15
#
#   byproduct_type  inclusion_pct water_condition processing Proteína (%)_media  \
# 0        control              0            none       none          14.567601
# 1        control              0            agar       none          12.755333
# 2        control              0        humidity       none          12.755333
# 3        control              0             dry       none          12.755333
# 4           hoja             15            none       none            12.9116
#
#   Proteína (%)_sd  ... PROTEINA (%)_mean GRASA (%)_mean QUITINA (%)_mean  \
# 0         0.33907  ...         43.284851      35.185199         6.325538
# 1        0.548518  ...         36.268667      36.186667              NaN
# 2        0.548518  ...         39.188333      37.466667              NaN
# 3        0.548518  ...         42.037667          31.69              NaN
# 4        0.186512  ...         45.721612      34.556509         5.836431
#
#   CENIZAS (%)_mean CARBOHIDRATOS (%)_mean TPC_larva_media__dup1  \
# 0         3.934642              11.269769              0.321229
# 1         3.432133                    NaN                   NaN
# 2            3.378                    NaN                   NaN
# 3         3.592833                    NaN                   NaN
# 4         4.134092               9.751356              0.363926
#
#   TPC_larva_sd__dup1 Dieta_comp Trat_comp Tratamiento
# 0           0.023088    Control         0           0
# 1                NaN    Control         A           A
# 2                NaN    Control         A           A
# 3                NaN    Control         A           A
# 4           0.029128     Hoja15         1           1
#
# [5 rows x 42 columns]

# %% [markdown]
# Full Quality Dataset

# %%
qual_all = pd.concat([make_unique_columns(qual_H), make_unique_columns(qual_T)], ignore_index=True, sort=False)
qual_all.head(5)
# Out:
#     species study_block diet_name    Dieta byproduct_type  inclusion_pct  \
# 0  Hermetia        main   Control  Control        control              0
# 1  Hermetia        main    Hoja15   Hoja15           hoja             15
# 2  Hermetia        main    Hoja30   Hoja30           hoja             30
# 3  Hermetia        main    Hoja50   Hoja50           hoja             50
# 4  Hermetia        main   Orujo30  Orujo30          orujo             30
#
#   water_condition processing Proteína (%)_media Proteína (%)_sd  ...  \
# 0            none       none          18.175156        0.435439  ...
# 1            none       none          16.838123        0.258047  ...
# 2            none       none          15.137502         0.23809  ...
# 3            none       none          13.511368        0.191933  ...
# 4            none       none          16.626013        0.017579  ...
#
#   PROTEINA (%)_mean GRASA (%)_mean QUITINA (%)_mean CENIZAS (%)_mean  \
# 0         31.936173      11.498079         3.916584        23.552521
# 1         31.417118       8.225027         9.298099        26.271347
# 2         24.417325      21.223611         9.744646        20.199422
# 3         23.370496      14.909885        11.421126        20.929722
# 4         30.321931      10.156761         8.908303        20.538848
#
#   CARBOHIDRATOS (%)_mean TPC_larva_media__dup1 TPC_larva_sd__dup1 Tratamiento  \
# 0              29.096643              0.432843           0.031135           0
# 1              24.788409              0.358376           0.017351           1
# 2              24.414996              0.442705           0.046997           2
# 3              29.368771               0.31179           0.020487           3
# 4              30.074157              0.351143           0.044412           4
#
#   Dieta_comp Trat_comp
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Save in CSV + Zip

# %%
out_dir = Path("C:\\Users\\maria\\Downloads\\Jose_lenovo\\TFG\\surrogate_models\\data\\entomotive_datasets")
out_dir.mkdir(parents=True, exist_ok=True)

csv_files=[]
def save_csv(df, name):
    p = out_dir / f"{name}.csv"
    df.to_csv(p, index=False)
    csv_files.append(p)

save_csv(prod_H_ds, "productivity_hermetia_lote")
save_csv(prod_T_ds, "productivity_tenebrio_lote")
save_csv(prod_all_ds, "productivity_all_lote")

save_csv(qual_H, "quality_hermetia_dieta")
save_csv(qual_T, "quality_tenebrio_dieta")
save_csv(qual_all, "quality_all_dieta")

zip_path = out_dir / "entomotive_datasets.zip"
with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as z:
    for f in csv_files:
        z.write(f, arcname=f.name)

# %% [markdown]
# ### Preview

# %%
print("Productividad (Hermetia) - fila=lote", prod_H_ds.head(8))
print("Productividad (Tenebrio) - fila=lote", prod_T_ds.head(8))
print("Calidad (Hermetia) - fila=dieta", qual_H.head(8))
print("Calidad (Tenebrio) - fila=dieta", qual_T.head(8))

sizes = pd.DataFrame([
    ["productivity_hermetia_lote", *prod_H_ds.shape],
    ["productivity_tenebrio_lote", *prod_T_ds.shape],
    ["productivity_all_lote", *prod_all_ds.shape],
    ["quality_hermetia_dieta", *qual_H.shape],
    ["quality_tenebrio_dieta", *qual_T.shape],
    ["quality_all_dieta", *qual_all.shape],
], columns=["dataset","rows","cols"])
print("Resumen tamaños datasets", sizes)

zip_path
# Out:
# Productividad (Hermetia) - fila=lote     species study_block diet_name    Dieta Tratamiento  Replica  \
# 0  Hermetia        main   Control  Control           0        1
# 1  Hermetia        main   Control  Control           0        2
# 2  Hermetia        main   Control  Control           0        3
# 3  Hermetia        main    Hoja15   Hoja15           1        1
# 4  Hermetia        main    Hoja15   Hoja15           1        2
# 5  Hermetia        main    Hoja15   Hoja15           1        3
# 6  Hermetia        main    Hoja30   Hoja30           2        1
# 7  Hermetia        main    Hoja30   Hoja30           2        2
#
#   byproduct_type  inclusion_pct water_condition processing  ...  \
# 0        control              0            none       none  ...
# 1        control              0            none       none  ...
# 2        control              0            none       none  ...
# 3           hoja             15            none       none  ...
# 4           hoja             15            none       none  ...
# 5           hoja             15            none       none  ...
# 6           hoja             30            none       none  ...
# 7           hoja             30            none       none  ...
#
#   Peso total del sustrato (g) al finalizar el periodo de alimentación  \
# 0                                        1884.437753
# 1                                        1391.567280
# 2                                        1334.673548
# 3                                        1330.567333
# 4                                        1069.702232
# 5                                        1531.583027
# 6                                        2004.220510
# 7                                        2367.366108
#
#   PROTEINA (%)  GRASA (%) QUITINA (%) CENIZAS (%) CARBOHIDRATOS (%)  \
# 0    32.298228   7.856994    4.536508   24.085233         31.223037
# 1    31.988273   9.178856    3.188548   23.805322         31.839000
# 2    31.522017  17.458388    4.024695   22.767007         24.227893
# 3    32.439877   8.138716   10.804604   25.394843         23.221962
# 4    31.861333   9.794866    7.392563   26.810799         24.140439
# 5    29.950143   6.741499    9.697131   26.608399         27.002828
# 6    24.518905  19.601502   10.359710   21.445639         24.074243
# 7    23.472592  24.635063   10.516834   19.906843         21.468668
#
#   TPC_dieta_media__dup1 TPC_dieta_sd__dup1 TPC_larva_media__dup1  \
# 0              0.180416           0.012046              0.432843
# 1              0.180416           0.012046              0.432843
# 2              0.180416           0.012046              0.432843
# 3               0.90341           0.100583              0.358376
# 4               0.90341           0.100583              0.358376
# 5               0.90341           0.100583              0.358376
# 6              1.616542           0.050153              0.442705
# 7              1.616542           0.050153              0.442705
#
#   TPC_larva_sd__dup1
# 0           0.031135
# 1           0.031135
# 2           0.031135
# 3           0.017351
# 4           0.017351
# 5           0.017351
# 6           0.046997
# 7           0.046997
#
# [8 rows x 43 columns]
# Productividad (Tenebrio) - fila=lote     species study_block diet_name    Dieta Tratamiento  Replica  \
# 0  Tenebrio        main   Control  Control           0        1
# 1  Tenebrio        main   Control  Control           0        2
# 2  Tenebrio        main   Control  Control           0        3
# 3  Tenebrio        main    Hoja15   Hoja15           1        1
# 4  Tenebrio        main    Hoja15   Hoja15           1        2
# 5  Tenebrio        main    Hoja15   Hoja15           1        3
# 6  Tenebrio        main    Hoja30   Hoja30           2        1
# 7  Tenebrio        main    Hoja30   Hoja30           2        2
#
#   byproduct_type  inclusion_pct water_condition processing  ...  \
# 0        control              0            none       none  ...
# 1        control              0            none       none  ...
# 2        control              0            none       none  ...
# 3           hoja             15            none       none  ...
# 4           hoja             15            none       none  ...
# 5           hoja             15            none       none  ...
# 6           hoja             30            none       none  ...
# 7           hoja             30            none       none  ...
#
#   TPC_larva_media__dup1 TPC_larva_sd__dup1 Tratamiento_prod Dieta_comp_prod  \
# 0              0.321229           0.023088                0         Control
# 1              0.321229           0.023088                0         Control
# 2              0.321229           0.023088                0         Control
# 3              0.363926           0.029128                1          Hoja15
# 4              0.363926           0.029128                1          Hoja15
# 5              0.363926           0.029128                1          Hoja15
# 6              0.399321           0.023432                2          Hoja30
# 7              0.399321           0.023432                2          Hoja30
#
#   Trat_comp_prod Tratamiento_larv Dieta_comp_larv Trat_comp_larv Dieta_comp  \
# 0              0                0         Control              0    Control
# 1              0                0         Control              0    Control
# 2              0                0         Control              0    Control
# 3              1                1          Hoja15              1     Hoja15
# 4              1                1          Hoja15              1     Hoja15
# 5              1                1          Hoja15              1     Hoja15
# 6              2                2          Hoja30              2     Hoja30
# 7              2                2          Hoja30              2     Hoja30
#
#   Trat_comp
# 0         0
# 1         0
# 2         0
# 3         1
# 4         1
# 5         1
# 6         2
# 7         2
#
# [8 rows x 51 columns]
# Calidad (Hermetia) - fila=dieta     species study_block diet_name    Dieta byproduct_type  inclusion_pct  \
# 0  Hermetia        main   Control  Control        control              0
# 1  Hermetia        main    Hoja15   Hoja15           hoja             15
# 2  Hermetia        main    Hoja30   Hoja30           hoja             30
# 3  Hermetia        main    Hoja50   Hoja50           hoja             50
# 4  Hermetia        main   Orujo30  Orujo30          orujo             30
# 5  Hermetia        main   Orujo50  Orujo50          orujo             50
# 6  Hermetia        main   Orujo70  Orujo70          orujo             70
# 7  Hermetia        main   Orujo90  Orujo90          orujo             90
#
#   water_condition processing Proteína (%)_media Proteína (%)_sd  ...  \
# 0            none       none          18.175156        0.435439  ...
# 1            none       none          16.838123        0.258047  ...
# 2            none       none          15.137502         0.23809  ...
# 3            none       none          13.511368        0.191933  ...
# 4            none       none          16.626013        0.017579  ...
# 5            none       none          14.938607        0.268863  ...
# 6            none       none          14.352349        0.212814  ...
# 7            none       none          12.528128        0.461024  ...
#
#   TPC_dieta_media__dup1 TPC_dieta_sd__dup1 PROTEINA (%)_mean GRASA (%)_mean  \
# 0              0.180416           0.012046         31.936173      11.498079
# 1               0.90341           0.100583         31.417118       8.225027
# 2              1.616542           0.050153         24.417325      21.223611
# 3              2.484336             0.3436         23.370496      14.909885
# 4              0.785741           0.110158         30.321931      10.156761
# 5              0.927282             0.1372         32.147393      11.032152
# 6              1.442567           0.023861         27.401729      16.292617
# 7              2.039841           0.083617         26.546877      20.862635
#
#   QUITINA (%)_mean CENIZAS (%)_mean CARBOHIDRATOS (%)_mean  \
# 0         3.916584        23.552521              29.096643
# 1         9.298099        26.271347              24.788409
# 2         9.744646        20.199422              24.414996
# 3        11.421126        20.929722              29.368771
# 4         8.908303        20.538848              30.074157
# 5         9.263182        19.584966              27.972306
# 6        15.318378        16.805797              24.181479
# 7        11.022776        16.990257              24.577455
#
#   TPC_larva_media__dup1 TPC_larva_sd__dup1 Tratamiento
# 0              0.432843           0.031135           0
# 1              0.358376           0.017351           1
# 2              0.442705           0.046997           2
# 3               0.31179           0.020487           3
# 4              0.351143           0.044412           4
# 5               0.31636           0.029121           5
# 6              0.393268           0.015449           6
# 7              0.593574           0.039074           7
#
# [8 rows x 40 columns]
# Calidad (Tenebrio) - fila=dieta     species      study_block               diet_name                   Dieta  \
# 0  Tenebrio             main                 Control                 Control
# 1  Tenebrio    water_control            Control Agar            Control Agar
# 2  Tenebrio    water_control  Control Humedad superf  Control Humedad superf
# 3  Tenebrio    water_control            Control Seco            Control Seco
# 4  Tenebrio             main                  Hoja15                  Hoja15
# 5  Tenebrio             main                  Hoja30                  Hoja30
# 6  Tenebrio             main                  Hoja50                  Hoja50
# 7  Tenebrio  coffee_orujillo              Orujillo15              Orujillo15
#
#   byproduct_type  inclusion_pct water_condition processing Proteína (%)_media  \
# 0        control              0            none       none          14.567601
# 1        control              0            agar       none          12.755333
# 2        control              0        humidity       none          12.755333
# 3        control              0             dry       none          12.755333
# 4           hoja             15            none       none            12.9116
# 5           hoja             30            none       none          11.924123
# 6           hoja             50            none       none          10.490727
# 7       orujillo             15            none       none          11.477033
#
#   Proteína (%)_sd  ... PROTEINA (%)_mean GRASA (%)_mean QUITINA (%)_mean  \
# 0         0.33907  ...         43.284851      35.185199         6.325538
# 1        0.548518  ...         36.268667      36.186667              NaN
# 2        0.548518  ...         39.188333      37.466667              NaN
# 3        0.548518  ...         42.037667          31.69              NaN
# 4        0.186512  ...         45.721612      34.556509         5.836431
# 5        0.193534  ...         43.800517       31.42034         6.883952
# 6        0.106684  ...         43.603417      32.652757         6.325816
# 7        0.480022  ...         35.437333      38.106667              NaN
#
#   CENIZAS (%)_mean CARBOHIDRATOS (%)_mean TPC_larva_media__dup1  \
# 0         3.934642              11.269769              0.321229
# 1         3.432133                    NaN                   NaN
# 2            3.378                    NaN                   NaN
# 3         3.592833                    NaN                   NaN
# 4         4.134092               9.751356              0.363926
# 5          4.40769              13.487501              0.399321
# 6          4.16898               13.24903              0.450093
# 7         3.461033                    NaN                   NaN
#
#   TPC_larva_sd__dup1  Dieta_comp Trat_comp Tratamiento
# 0           0.023088     Control         0           0
# 1                NaN     Control         A           A
# 2                NaN     Control         A           A
# 3                NaN     Control         A           A
# 4           0.029128      Hoja15         1           1
# 5           0.023432      Hoja30         2           2
# 6            0.02167      Hoja50         3           3
# 7                NaN  Orujillo15         D           D
#
# [8 rows x 42 columns]
# Resumen tamaños datasets                       dataset  rows  cols
# 0  productivity_hermetia_lote    33    43
# 1  productivity_tenebrio_lote    57    51
# 2       productivity_all_lote    90    51
# 3      quality_hermetia_dieta    11    40
# 4      quality_tenebrio_dieta    19    42
# 5           quality_all_dieta    30    42
# WindowsPath('C:/Users/maria/Downloads/Jose_lenovo/TFG/surrogate_models/data/entomotive_datasets/entomotive_datasets.zip')
